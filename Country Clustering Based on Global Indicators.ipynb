# %%
#import the relevant Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Data Preprocessing

# %%
data=pd.read_csv(r"C:\Users\Namukaba Katambo\Desktop\NK\Datasets for practice\world-data-2023.csv")
data.head()
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0  Afghanistan               60           AF                58.10%
# 1      Albania              105           AL                43.10%
# 2      Algeria               18           DZ                17.40%
# 3      Andorra              164           AD                40.00%
# 4       Angola               26           AO                47.50%
#
#   Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0        652,230           323,000       32.49          93.0
# 1         28,748             9,000       11.78         355.0
# 2      2,381,741           317,000       24.28         213.0
# 3            468               NaN        7.20         376.0
# 4      1,246,700           117,000       40.73         244.0
#
#   Capital/Major City Co2-Emissions  ... Out of pocket health expenditure  \
# 0              Kabul         8,672  ...                           78.40%
# 1             Tirana         4,536  ...                           56.90%
# 2            Algiers       150,006  ...                           28.10%
# 3   Andorra la Vella           469  ...                           36.40%
# 4             Luanda        34,693  ...                           33.40%
#
#   Physicians per thousand  Population  \
# 0                    0.28  38,041,754
# 1                    1.20   2,854,191
# 2                    1.72  43,053,054
# 3                    3.33      77,142
# 4                    0.21  31,825,295
#
#    Population: Labor force participation (%) Tax revenue (%) Total tax rate  \
# 0                                     48.90%           9.30%         71.40%
# 1                                     55.70%          18.60%         36.60%
# 2                                     41.20%          37.20%         66.10%
# 3                                        NaN             NaN            NaN
# 4                                     77.50%           9.20%         49.10%
#
#   Unemployment rate Urban_population   Latitude  Longitude
# 0            11.12%        9,797,273  33.939110  67.709953
# 1            12.33%        1,747,593  41.153332  20.168331
# 2            11.70%       31,510,100  28.033886   1.659626
# 3               NaN           67,873  42.506285   1.521801
# 4             6.89%       21,061,025 -11.202692  17.873887
#
# [5 rows x 35 columns]

# %%
data.dtypes
# Out:
# Country                                       object
# Density\n(P/Km2)                              object
# Abbreviation                                  object
# Agricultural Land( %)                         object
# Land Area(Km2)                                object
# Armed Forces size                             object
# Birth Rate                                   float64
# Calling Code                                 float64
# Capital/Major City                            object
# Co2-Emissions                                 object
# CPI                                           object
# CPI Change (%)                                object
# Currency-Code                                 object
# Fertility Rate                               float64
# Forested Area (%)                             object
# Gasoline Price                                object
# GDP                                           object
# Gross primary education enrollment (%)        object
# Gross tertiary education enrollment (%)       object
# Infant mortality                             float64
# Largest city                                  object
# Life expectancy                              float64
# Maternal mortality ratio                     float64
# Minimum wage                                  object
# Official language                             object
# Out of pocket health expenditure              object
# Physicians per thousand                      float64
# Population                                    object
# Population: Labor force participation (%)     object
# Tax revenue (%)                               object
# Total tax rate                                object
# Unemployment rate                             object
# Urban_population                              object
# Latitude                                     float64
# Longitude                                    float64
# dtype: object

# %%
#Converting the Object Data types to numerical values
data['Density\n(P/Km2)'] = data['Density\n(P/Km2)'].str.replace(',', '').astype(float)
data['Agricultural Land( %)'] = data['Agricultural Land( %)'].str.replace('%', '').astype(float)
data['Land Area(Km2)'] = data['Land Area(Km2)'].str.replace(',', '').astype(float)
data['Co2-Emissions'] = data['Co2-Emissions'].str.replace(',', '').astype(float)
data['Urban_population'] = data['Urban_population'].str.replace(',', '').astype(float)
data['CPI Change (%)'] = data['CPI Change (%)'].str.replace('%', '').astype(float)
data['Forested Area (%)'] = data['Forested Area (%)'].str.replace('%', '').astype(float)
data['Gross primary education enrollment (%)'] = data['Gross primary education enrollment (%)'].str.replace('%', '').astype(float)
data['Gross tertiary education enrollment (%)'] = data['Gross tertiary education enrollment (%)'].str.replace('%', '').astype(float)
data['Population: Labor force participation (%)'] = data['Population: Labor force participation (%)'].str.replace('%', '').astype(float)
data['Tax revenue (%)'] = data['Tax revenue (%)'].str.replace('%', '').astype(float)
data['Armed Forces size'] = data['Armed Forces size'].str.replace(',', '').astype(float)
data['CPI'] = data['CPI'].str.replace(',', '').astype(float)
data['Gasoline Price'] = data['Gasoline Price'].str.replace('$', '').astype(float)
data['Unemployment rate'] = data['Unemployment rate'].str.replace('%', '').astype(float)
data['Total tax rate'] = data['Total tax rate'].str.replace('%', '').astype(float)
data['Population'] = data['Population'].str.replace(',', '').astype(float)
data['Minimum wage'] = data['Minimum wage'].str.replace('$', '').astype(float)
data['Out of pocket health expenditure'] = data['Out of pocket health expenditure'].str.replace('%', '').astype(float)
data['GDP'] = data['GDP'].str.replace('$', '')
data['GDP'] = data['GDP'].str.replace(',', '').astype(float)

# %%
data.dtypes
# Out:
# Country                                       object
# Density\n(P/Km2)                             float64
# Abbreviation                                  object
# Agricultural Land( %)                        float64
# Land Area(Km2)                               float64
# Armed Forces size                            float64
# Birth Rate                                   float64
# Calling Code                                 float64
# Capital/Major City                            object
# Co2-Emissions                                float64
# CPI                                          float64
# CPI Change (%)                               float64
# Currency-Code                                 object
# Fertility Rate                               float64
# Forested Area (%)                            float64
# Gasoline Price                               float64
# GDP                                          float64
# Gross primary education enrollment (%)       float64
# Gross tertiary education enrollment (%)      float64
# Infant mortality                             float64
# Largest city                                  object
# Life expectancy                              float64
# Maternal mortality ratio                     float64
# Minimum wage                                 float64
# Official language                             object
# Out of pocket health expenditure             float64
# Physicians per thousand                      float64
# Population                                   float64
# Population: Labor force participation (%)    float64
# Tax revenue (%)                              float64
# Total tax rate                               float64
# Unemployment rate                            float64
# Urban_population                             float64
# Latitude                                     float64
# Longitude                                    float64
# dtype: object

# %%
#removing columns with no value for this project including logitute and latitude which can affect the clustering due to location
data.drop(columns=['Abbreviation','Calling Code','Capital/Major City','Latitude','Longitude','Currency-Code','Largest city','Official language'], inplace=True)

# %%
data.columns
# Out:
# Index(['Country', 'Density\n(P/Km2)', 'Agricultural Land( %)',
#        'Land Area(Km2)', 'Armed Forces size', 'Birth Rate', 'Co2-Emissions',
#        'CPI', 'CPI Change (%)', 'Fertility Rate', 'Forested Area (%)',
#        'Gasoline Price', 'GDP', 'Gross primary education enrollment (%)',
#        'Gross tertiary education enrollment (%)', 'Infant mortality',
#        'Life expectancy', 'Maternal mortality ratio', 'Minimum wage',
#        'Out of pocket health expenditure', 'Physicians per thousand',
#        'Population', 'Population: Labor force participation (%)',
#        'Tax revenue (%)', 'Total tax rate', 'Unemployment rate',
#        'Urban_population'],
#       dtype='object')

# %%
data.describe()
# Out:
#        Density\n(P/Km2)  Agricultural Land( %)  Land Area(Km2)  \
# count        195.000000             188.000000    1.940000e+02
# mean         356.764103              39.117553    6.896244e+05
# std         1982.888967              21.783052    1.921609e+06
# min            2.000000               0.600000    0.000000e+00
# 25%           35.500000              21.700000    2.382825e+04
# 50%           89.000000              39.600000    1.195110e+05
# 75%          216.500000              55.375000    5.242560e+05
# max        26337.000000              82.600000    1.709824e+07
#
#        Armed Forces size  Birth Rate  Co2-Emissions          CPI  \
# count       1.710000e+02  189.000000   1.880000e+02   178.000000
# mean        1.592749e+05   20.214974   1.777992e+05   190.460955
# std         3.806288e+05    9.945774   8.387903e+05   397.947380
# min         0.000000e+00    5.900000   1.100000e+01    99.030000
# 25%         1.100000e+04   11.300000   2.304250e+03   113.885000
# 50%         3.100000e+04   17.950000   1.230300e+04   125.340000
# 75%         1.420000e+05   28.750000   6.388425e+04   157.265000
# max         3.031000e+06   46.080000   9.893038e+06  4583.710000
#
#        CPI Change (%)  Fertility Rate  Forested Area (%)  ...  \
# count      179.000000      188.000000         188.000000  ...
# mean         6.722346        2.698138          32.015426  ...
# std         24.450414        1.282267          23.791331  ...
# min         -4.300000        0.980000           0.000000  ...
# 25%          1.000000        1.705000          11.000000  ...
# 50%          2.300000        2.245000          32.000000  ...
# 75%          4.250000        3.597500          48.175000  ...
# max        254.900000        6.910000          98.300000  ...
#
#        Maternal mortality ratio  Minimum wage  \
# count                181.000000    150.000000
# mean                 160.392265      2.194133
# std                  233.502024      2.970796
# min                    2.000000      0.010000
# 25%                   13.000000      0.402500
# 50%                   53.000000      1.045000
# 75%                  186.000000      2.447500
# max                 1150.000000     13.590000
#
#        Out of pocket health expenditure  Physicians per thousand  \
# count                        188.000000               188.000000
# mean                          32.637234                 1.839840
# std                           19.172697                 1.684261
# min                            0.200000                 0.010000
# 25%                           17.450000                 0.332500
# 50%                           30.700000                 1.460000
# 75%                           43.975000                 2.935000
# max                           81.600000                 8.420000
#
#          Population  Population: Labor force participation (%)  \
# count  1.940000e+02                                 176.000000
# mean   3.938116e+07                                  62.738068
# std    1.450924e+08                                  10.502907
# min    8.360000e+02                                  38.000000
# 25%    1.962678e+06                                  56.150000
# 50%    8.826588e+06                                  62.450000
# 75%    2.858549e+07                                  69.500000
# max    1.397715e+09                                  86.800000
#
#        Tax revenue (%)  Total tax rate  Unemployment rate  Urban_population
# count       169.000000      183.000000         176.000000      1.900000e+02
# mean         16.573964       40.822404           6.886364      2.230454e+07
# std           6.961632       20.557662           5.079216      7.543050e+07
# min           0.000000        8.000000           0.090000      5.464000e+03
# 25%          11.700000       30.600000           3.395000      1.152961e+06
# 50%          16.300000       37.200000           5.360000      4.678104e+06
# 75%          21.100000       48.000000           9.490000      1.490324e+07
# max          37.200000      219.600000          28.180000      8.429340e+08
#
# [8 rows x 26 columns]

# %%
data.isnull().sum()
# Out:
# Country                                       0
# Density\n(P/Km2)                              0
# Agricultural Land( %)                         7
# Land Area(Km2)                                1
# Armed Forces size                            24
# Birth Rate                                    6
# Co2-Emissions                                 7
# CPI                                          17
# CPI Change (%)                               16
# Fertility Rate                                7
# Forested Area (%)                             7
# Gasoline Price                               20
# GDP                                           2
# Gross primary education enrollment (%)        7
# Gross tertiary education enrollment (%)      12
# Infant mortality                              6
# Life expectancy                               8
# Maternal mortality ratio                     14
# Minimum wage                                 45
# Out of pocket health expenditure              7
# Physicians per thousand                       7
# Population                                    1
# Population: Labor force participation (%)    19
# Tax revenue (%)                              26
# Total tax rate                               12
# Unemployment rate                            19
# Urban_population                              5
# dtype: int64

# %%
df=data.dropna()
df.head()
# Out:
#        Country  Density\n(P/Km2)  Agricultural Land( %)  Land Area(Km2)  \
# 0  Afghanistan              60.0                   58.1        652230.0
# 1      Albania             105.0                   43.1         28748.0
# 2      Algeria              18.0                   17.4       2381741.0
# 4       Angola              26.0                   47.5       1246700.0
# 6    Argentina              17.0                   54.3       2780400.0
#
#    Armed Forces size  Birth Rate  Co2-Emissions     CPI  CPI Change (%)  \
# 0           323000.0       32.49         8672.0  149.90             2.3
# 1             9000.0       11.78         4536.0  119.05             1.4
# 2           317000.0       24.28       150006.0  151.36             2.0
# 4           117000.0       40.73        34693.0  261.73            17.1
# 6           105000.0       17.02       201348.0  232.75            53.5
#
#    Fertility Rate  ...  Maternal mortality ratio  Minimum wage  \
# 0            4.47  ...                     638.0          0.43
# 1            1.62  ...                      15.0          1.12
# 2            3.02  ...                     112.0          0.95
# 4            5.52  ...                     241.0          0.71
# 6            2.26  ...                      39.0          3.35
#
#    Out of pocket health expenditure  Physicians per thousand  Population  \
# 0                              78.4                     0.28  38041754.0
# 1                              56.9                     1.20   2854191.0
# 2                              28.1                     1.72  43053054.0
# 4                              33.4                     0.21  31825295.0
# 6                              17.6                     3.96  44938712.0
#
#    Population: Labor force participation (%)  Tax revenue (%)  Total tax rate  \
# 0                                       48.9              9.3            71.4
# 1                                       55.7             18.6            36.6
# 2                                       41.2             37.2            66.1
# 4                                       77.5              9.2            49.1
# 6                                       61.3             10.1           106.3
#
#    Unemployment rate  Urban_population
# 0              11.12         9797273.0
# 1              12.33         1747593.0
# 2              11.70        31510100.0
# 4               6.89        21061025.0
# 6               9.79        41339571.0
#
# [5 rows x 27 columns]

# %%
df.shape
# Out:
# (120, 27)

# %%
df.set_index('Country', inplace=True)
df.head()
# Out:
#              Density\n(P/Km2)  Agricultural Land( %)  Land Area(Km2)  \
# Country
# Afghanistan              60.0                   58.1        652230.0
# Albania                 105.0                   43.1         28748.0
# Algeria                  18.0                   17.4       2381741.0
# Angola                   26.0                   47.5       1246700.0
# Argentina                17.0                   54.3       2780400.0
#
#              Armed Forces size  Birth Rate  Co2-Emissions     CPI  \
# Country
# Afghanistan           323000.0       32.49         8672.0  149.90
# Albania                 9000.0       11.78         4536.0  119.05
# Algeria               317000.0       24.28       150006.0  151.36
# Angola                117000.0       40.73        34693.0  261.73
# Argentina             105000.0       17.02       201348.0  232.75
#
#              CPI Change (%)  Fertility Rate  Forested Area (%)  ...  \
# Country                                                         ...
# Afghanistan             2.3            4.47                2.1  ...
# Albania                 1.4            1.62               28.1  ...
# Algeria                 2.0            3.02                0.8  ...
# Angola                 17.1            5.52               46.3  ...
# Argentina              53.5            2.26                9.8  ...
#
#              Maternal mortality ratio  Minimum wage  \
# Country
# Afghanistan                     638.0          0.43
# Albania                          15.0          1.12
# Algeria                         112.0          0.95
# Angola                          241.0          0.71
# Argentina                        39.0          3.35
#
#              Out of pocket health expenditure  Physicians per thousand  \
# Country
# Afghanistan                              78.4                     0.28
# Albania                                  56.9                     1.20
# Algeria                                  28.1                     1.72
# Angola                                   33.4                     0.21
# Argentina                                17.6                     3.96
#
#              Population  Population: Labor force participation (%)  \
# Country
# Afghanistan  38041754.0                                       48.9
# Albania       2854191.0                                       55.7
# Algeria      43053054.0                                       41.2
# Angola       31825295.0                                       77.5
# Argentina    44938712.0                                       61.3
#
#              Tax revenue (%)  Total tax rate  Unemployment rate  \
# Country
# Afghanistan              9.3            71.4              11.12
# Albania                 18.6            36.6              12.33
# Algeria                 37.2            66.1              11.70
# Angola                   9.2            49.1               6.89
# Argentina               10.1           106.3               9.79
#
#              Urban_population
# Country
# Afghanistan         9797273.0
# Albania             1747593.0
# Algeria            31510100.0
# Angola             21061025.0
# Argentina          41339571.0
#
# [5 rows x 26 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#saving the cleaned dataframe to be used for the next clustering methods
df.to_csv('data.csv')

# %% [markdown]
# # Correlation Between variables

# %%
#correlation between the variables
plt.figure(figsize=(12,10))
sns.heatmap(data.corr(), annot=False, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
#factors with high correlation 
correlation_matrix = data.corr()
highly_correlated_factors = correlation_matrix[(correlation_matrix >= 0.75) & (correlation_matrix < 1)].stack().reset_index()
highly_correlated_factors.columns = ['Factor1', 'Factor2', 'Correlation']

for index, row in highly_correlated_factors.iterrows():
    plt.figure(figsize=(3, 2))
    sns.scatterplot(data=data, x=row['Factor1'], y=row['Factor2'])
    plt.title(f"Scatter Plot: {row['Factor1']} vs {row['Factor2']} (Correlation: {row['Correlation']:.2f})")
    plt.xlabel(row['Factor1'])
    plt.ylabel(row['Factor2'])
    plt.show()

# %% [markdown]
# # Standardize the data

# %%
#standardize the data
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df1=scaler.fit_transform(df)

# %% [markdown]
# K-means clustering is based on the distance between data points. By standardizing the features to have a mean of 0 and a standard deviation of 1, all features are treated equally in terms of their influence on the clustering process. This is important because K-means is a distance-based algorithm, and features with larger scales could dominate the clustering process
# Standardization ensures that each feature has the same weight during the computation of cluster centers (centroids). When features are on different scales, some features may have a larger influence on the cluster centers, leading to suboptimal results.

# %% [markdown]
# # K means Clustering

# %%
#using the Elbow Method to determine the optimal number of clusters
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(df1)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
kmeans = KMeans(n_clusters=4, max_iter=50)
kmeans.fit(df1)
# Out:
# KMeans(max_iter=50, n_clusters=4)

# %%
 kmeans.labels_
# Out:
# array([1, 3, 3, 1, 3, 3, 0, 3, 3, 3, 0, 0, 3, 1, 3, 3, 3, 0, 1, 1, 3, 1,
#        0, 1, 0, 2, 3, 1, 3, 0, 0, 1, 3, 3, 0, 3, 0, 1, 1, 3, 0, 1, 0, 3,
#        3, 0, 2, 3, 3, 3, 0, 0, 3, 0, 3, 3, 1, 3, 3, 1, 0, 3, 1, 1, 0, 0,
#        1, 1, 3, 1, 0, 3, 3, 3, 3, 3, 1, 3, 3, 0, 0, 3, 1, 1, 3, 1, 1, 3,
#        3, 3, 0, 0, 0, 2, 3, 1, 3, 1, 0, 0, 0, 0, 3, 1, 3, 3, 1, 3, 1, 1,
#        3, 3, 3, 1, 3, 0, 2, 0, 3, 1])

# %% [markdown]
# # Cluster Identification for each country

# %%
df['Cluster_Id'] = kmeans.labels_
df.head()
# Out:
#              Density\n(P/Km2)  Agricultural Land( %)  Land Area(Km2)  \
# Country
# Afghanistan              60.0                   58.1        652230.0
# Albania                 105.0                   43.1         28748.0
# Algeria                  18.0                   17.4       2381741.0
# Angola                   26.0                   47.5       1246700.0
# Argentina                17.0                   54.3       2780400.0
#
#              Armed Forces size  Birth Rate  Co2-Emissions     CPI  \
# Country
# Afghanistan           323000.0       32.49         8672.0  149.90
# Albania                 9000.0       11.78         4536.0  119.05
# Algeria               317000.0       24.28       150006.0  151.36
# Angola                117000.0       40.73        34693.0  261.73
# Argentina             105000.0       17.02       201348.0  232.75
#
#              CPI Change (%)  Fertility Rate  Forested Area (%)  ...  \
# Country                                                         ...
# Afghanistan             2.3            4.47                2.1  ...
# Albania                 1.4            1.62               28.1  ...
# Algeria                 2.0            3.02                0.8  ...
# Angola                 17.1            5.52               46.3  ...
# Argentina              53.5            2.26                9.8  ...
#
#              Minimum wage  Out of pocket health expenditure  \
# Country
# Afghanistan          0.43                              78.4
# Albania              1.12                              56.9
# Algeria              0.95                              28.1
# Angola               0.71                              33.4
# Argentina            3.35                              17.6
#
#              Physicians per thousand  Population  \
# Country
# Afghanistan                     0.28  38041754.0
# Albania                         1.20   2854191.0
# Algeria                         1.72  43053054.0
# Angola                          0.21  31825295.0
# Argentina                       3.96  44938712.0
#
#              Population: Labor force participation (%)  Tax revenue (%)  \
# Country
# Afghanistan                                       48.9              9.3
# Albania                                           55.7             18.6
# Algeria                                           41.2             37.2
# Angola                                            77.5              9.2
# Argentina                                         61.3             10.1
#
#              Total tax rate  Unemployment rate  Urban_population  Cluster_Id
# Country
# Afghanistan            71.4              11.12         9797273.0           1
# Albania                36.6              12.33         1747593.0           3
# Algeria                66.1              11.70        31510100.0           3
# Angola                 49.1               6.89        21061025.0           1
# Argentina             106.3               9.79        41339571.0           3
#
# [5 rows x 27 columns]

# %%
df[df['Cluster_Id']==0]
# Out:
#                      Density\n(P/Km2)  Agricultural Land( %)  Land Area(Km2)  \
# Country
# Australia                         3.0                   48.2       7741220.0
# Barbados                        668.0                   23.3           430.0
# Belgium                         383.0                   44.6         30528.0
# Bulgaria                         64.0                   46.3        110879.0
# Canada                            4.0                    6.9       9984670.0
# Chile                            26.0                   21.2        756096.0
# Croatia                          73.0                   27.6         56594.0
# Czech Republic                  139.0                   45.2         78867.0
# Estonia                          31.0                   23.1         45228.0
# France                          119.0                   52.4        643801.0
# Germany                         240.0                   47.7        357022.0
# Greece                           81.0                   47.6        131957.0
# Hungary                         107.0                   58.4         93028.0
# Republic of Ireland              72.0                   64.5         70273.0
# Israel                          400.0                   24.6         20770.0
# Japan                           347.0                   12.3        377944.0
# Latvia                           30.0                   31.1         64589.0
# Lithuania                        43.0                   47.2         65300.0
# Luxembourg                      242.0                   53.7          2586.0
# Malta                          1380.0                   32.4           316.0
# Netherlands                     508.0                   53.3         41543.0
# New Zealand                      18.0                   40.5        268838.0
# Poland                          124.0                   46.9        312685.0
# Portugal                        111.0                   39.5         92212.0
# Romania                          84.0                   58.8        238391.0
# Slovakia                        114.0                   39.2         49035.0
# Slovenia                        103.0                   30.7         20273.0
# South Korea                     527.0                   17.4         99720.0
# Spain                            94.0                   52.6        505370.0
# United Kingdom                  281.0                   71.7        243610.0
# Uruguay                          20.0                   82.6        176215.0
#
#                      Armed Forces size  Birth Rate  Co2-Emissions     CPI  \
# Country
# Australia                      58000.0       12.60       375908.0  119.80
# Barbados                        1000.0       10.65         1276.0  134.09
# Belgium                        32000.0       10.30        96889.0  117.11
# Bulgaria                       31000.0        8.90        41708.0  114.42
# Canada                         72000.0       10.10       544894.0  116.76
# Chile                         122000.0       12.43        85822.0  131.91
# Croatia                        18000.0        9.00        17488.0  109.82
# Czech Republic                 23000.0       10.70       102218.0  116.48
# Estonia                         6000.0       10.90        16590.0  122.14
# France                        307000.0       11.30       303276.0  110.05
# Germany                       180000.0        9.50       727973.0  112.85
# Greece                        146000.0        8.10        62434.0  101.87
# Hungary                        40000.0        9.60        45537.0  121.64
# Republic of Ireland             9000.0       12.50        37711.0  106.58
# Israel                        178000.0       20.80        65166.0  108.15
# Japan                         261000.0        7.40      1135886.0  105.48
# Latvia                          6000.0       10.00         7004.0  116.86
# Lithuania                      34000.0       10.00        12963.0  118.38
# Luxembourg                      2000.0       10.30         8988.0  115.09
# Malta                           2000.0        9.20         1342.0  113.45
# Netherlands                    41000.0        9.70       170780.0  115.91
# New Zealand                     9000.0       11.98        34382.0  114.24
# Poland                        191000.0       10.20       299037.0  114.11
# Portugal                       52000.0        8.50        48742.0  110.62
# Romania                       126000.0        9.60        69259.0  123.78
# Slovakia                       16000.0       10.60        32424.0  115.34
# Slovenia                        7000.0        9.40        12633.0  111.05
# South Korea                   634000.0        6.40       620302.0  115.16
# Spain                         196000.0        7.90       244002.0  110.96
# United Kingdom                148000.0       11.00       379025.0  119.62
# Uruguay                        22000.0       13.86         6766.0  202.92
#
#                      CPI Change (%)  Fertility Rate  Forested Area (%)  ...  \
# Country                                                                 ...
# Australia                       1.6            1.74               16.3  ...
# Barbados                        4.1            1.62               14.7  ...
# Belgium                         1.4            1.62               22.6  ...
# Bulgaria                        3.1            1.56               35.4  ...
# Canada                          1.9            1.50               38.2  ...
# Chile                           2.6            1.65               24.3  ...
# Croatia                         0.8            1.47               34.4  ...
# Czech Republic                  2.8            1.69               34.6  ...
# Estonia                         2.3            1.59               51.3  ...
# France                          1.1            1.88               31.2  ...
# Germany                         1.4            1.56               32.7  ...
# Greece                          0.2            1.35               31.7  ...
# Hungary                         3.3            1.54               22.9  ...
# Republic of Ireland             0.9            1.75               11.0  ...
# Israel                          0.8            3.09                7.7  ...
# Japan                           0.5            1.42               68.5  ...
# Latvia                          2.8            1.60               54.0  ...
# Lithuania                       2.3            1.63               34.8  ...
# Luxembourg                      1.7            1.37               35.7  ...
# Malta                           1.6            1.23                1.1  ...
# Netherlands                     2.6            1.59               11.2  ...
# New Zealand                     1.6            1.71               38.6  ...
# Poland                          2.2            1.46               30.9  ...
# Portugal                        0.3            1.38               34.6  ...
# Romania                         3.8            1.71               30.1  ...
# Slovakia                        2.7            1.52               40.4  ...
# Slovenia                        1.6            1.60               62.0  ...
# South Korea                     0.4            0.98               63.4  ...
# Spain                           0.7            1.26               36.9  ...
# United Kingdom                  1.7            1.68               13.1  ...
# Uruguay                         7.9            1.97               10.7  ...
# Zambia                                 36.19         5141.0   212.31
#
#                                   CPI Change (%)  Fertility Rate  \
# Country
# Afghanistan                                  2.3            4.47
# Angola                                      17.1            5.52
# Benin                                       -0.9            4.84
# Burkina Faso                                -3.2            5.19
# Ivory Coast                                 -0.9            4.65
# Cameroon                                     2.5            4.57
# Central African Republic                    37.1            4.72
# Republic of the Congo                        2.2            4.43
# Democratic Republic of the Congo             2.9            5.92
# Gabon                                        2.1            3.97
# The Gambia                                   7.1            5.22
# Ghana                                        7.2            3.87
# Kenya                                        4.7            3.49
# Laos                                         3.3            2.67
# Lesotho                                      5.2            3.14
# Liberia                                     23.6            4.32
# Madagascar                                   5.6            4.08
# Malawi                                       9.4            4.21
# Mali                                        -1.7            5.88
# Mozambique                                   2.8            4.85
# Niger                                       -2.5            6.91
# Nigeria                                     11.4            5.39
# Pakistan                                    10.6            3.51
# Papua New Guinea                             3.6            3.56
# Senegal                                      1.8            4.63
# Sierra Leone                                14.8            4.26
# Sudan                                       51.0            4.41
# Tanzania                                     3.5            4.89
# East Timor                                   2.6            4.02
# Togo                                         0.7            4.32
# Uganda                                       2.9            4.96
# Zambia                                       9.2            4.63
#
#                                   Forested Area (%)  ...  Minimum wage  \
# Country                                              ...
# Afghanistan                                     2.1  ...          0.43
# Angola                                         46.3  ...          0.71
# Benin                                          37.8  ...          0.39
# Burkina Faso                                   19.3  ...          0.34
# Ivory Coast                                    32.7  ...          0.36
# Cameroon                                       39.3  ...          0.35
# Central African Republic                       35.6  ...          0.37
# Republic of the Congo                          65.4  ...          0.88
# Democratic Republic of the Congo               67.2  ...          0.18
# Gabon                                          90.0  ...          1.46
# The Gambia                                     48.4  ...          0.13
# Ghana                                          41.2  ...          0.27
# Kenya                                           7.8  ...          0.25
# Laos                                           82.1  ...          0.83
# Lesotho                                         1.6  ...          0.41
# Liberia                                        43.1  ...          0.17
# Madagascar                                     21.4  ...          0.21
# Malawi                                         33.2  ...          0.12
# Mali                                            3.8  ...          0.23
# Mozambique                                     48.0  ...          0.27
# Niger                                           0.9  ...          0.29
# Nigeria                                         7.2  ...          0.54
# Pakistan                                        1.9  ...          0.69
# Papua New Guinea                               74.1  ...          1.16
# Senegal                                        42.8  ...          0.31
# Sierra Leone                                   43.1  ...          0.57
# Sudan                                           8.1  ...          0.41
# Tanzania                                       51.6  ...          0.09
# East Timor                                     45.4  ...          0.60
# Togo                                            3.1  ...          0.34
# Uganda                                          9.7  ...          0.01
# Zambia                                         65.2  ...          0.24
#
#                                   Out of pocket health expenditure  \
# Country
# Afghanistan                                                   78.4
# Angola                                                        33.4
# Benin                                                         40.5
# Burkina Faso                                                  36.1
# Ivory Coast                                                   36.0
# Cameroon                                                      69.7
# Central African Republic                                      39.6
# Republic of the Congo                                         43.8
# Democratic Republic of the Congo                              37.4
# Gabon                                                         25.9
# The Gambia                                                    20.3
# Ghana                                                         36.1
# Kenya                                                         33.4
# Laos                                                          45.4
# Lesotho                                                       16.9
# Liberia                                                       19.6
# Madagascar                                                    21.7
# Malawi                                                        11.0
# Mali                                                          46.3
# Mozambique                                                     6.8
# Niger                                                         52.3
# Nigeria                                                       72.2
# Pakistan                                                      66.5
# Papua New Guinea                                               5.8
# Senegal                                                       44.2
# Sierra Leone                                                  38.2
# Sudan                                                         63.2
# Tanzania                                                      26.1
# East Timor                                                    10.2
# Togo                                                          51.0
# Uganda                                                        40.5
# Zambia                                                        27.5
#
#                                   Physicians per thousand   Population  \
# Country
# Afghanistan                                          0.28   38041754.0
# Angola                                               0.21   31825295.0
# Benin                                                0.08   11801151.0
# Burkina Faso                                         0.08   20321378.0
# Ivory Coast                                          0.23   25716544.0
# Cameroon                                             0.09   25876380.0
# Central African Republic                             0.06    4745185.0
# Republic of the Congo                                0.12    5380508.0
# Democratic Republic of the Congo                     0.07   86790567.0
# Gabon                                                0.68    2172579.0
# The Gambia                                           0.10    2347706.0
# Ghana                                                0.14   30792608.0
# Kenya                                                0.16   52573973.0
# Laos                                                 0.37    7169455.0
# Lesotho                                              0.07    2125268.0
# Liberia                                              0.04    4937374.0
# Madagascar                                           0.18   26969307.0
# Malawi                                               0.04   18628747.0
# Mali                                                 0.13   19658031.0
# Mozambique                                           0.08   30366036.0
# Niger                                                0.04   23310715.0
# Nigeria                                              0.38  200963599.0
# Pakistan                                             0.98  216565318.0
# Papua New Guinea                                     0.07    8776109.0
# Senegal                                              0.07   16296364.0
# Sierra Leone                                         0.03    7813215.0
# Sudan                                                0.26   42813238.0
# Tanzania                                             0.01   58005463.0
# East Timor                                           0.72    3500000.0
# Togo                                                 0.08    8082366.0
# Uganda                                               0.17   44269594.0
# Zambia                                               1.19   17861030.0
#
#                                   Population: Labor force participation (%)  \
# Country
# Afghanistan                                                            48.9
# Angola                                                                 77.5
# Benin                                                                  70.9
# Burkina Faso                                                           66.4
# Ivory Coast                                                            57.0
# Cameroon                                                               76.1
# Central African Republic                                               72.0
# Republic of the Congo                                                  69.4
# Democratic Republic of the Congo                                       63.5
# Gabon                                                                  52.9
# The Gambia                                                             59.4
# Ghana                                                                  67.8
# Kenya                                                                  74.7
# Laos                                                                   78.5
# Lesotho                                                                67.9
# Liberia                                                                76.3
# Madagascar                                                             86.1
# Malawi                                                                 76.7
# Mali                                                                   70.8
# Mozambique                                                             78.1
# Niger                                                                  72.0
# Nigeria                                                                52.9
# Pakistan                                                               52.6
# Papua New Guinea                                                       47.2
# Senegal                                                                45.7
# Sierra Leone                                                           57.9
# Sudan                                                                  48.4
# Tanzania                                                               83.4
# East Timor                                                             67.3
# Togo                                                                   77.6
# Uganda                                                                 70.3
# Zambia                                                                 74.6
#
#                                   Tax revenue (%)  Total tax rate  \
# Country
# Afghanistan                                   9.3            71.4
# Angola                                        9.2            49.1
# Benin                                        10.8            48.9
# Burkina Faso                                 15.0            41.3
# Ivory Coast                                  11.8            50.1
# Cameroon                                     12.8            57.7
# Central African Republic                      8.6            73.3
# Republic of the Congo                         9.0            54.3
# Democratic Republic of the Congo             10.7            50.7
# Gabon                                        10.2            47.1
# The Gambia                                    9.4            48.4
# Ghana                                        12.6            55.4
# Kenya                                        15.1            37.2
# Laos                                         12.9            24.1
# Lesotho                                      31.6            13.6
# Liberia                                      12.9            46.2
# Madagascar                                   10.2            38.3
# Malawi                                       17.3            34.5
# Mali                                         11.6            54.5
# Mozambique                                    0.0            36.1
# Niger                                        11.8            47.2
# Nigeria                                       1.5            34.8
# Pakistan                                      9.2            33.9
# Papua New Guinea                             13.6            37.1
# Senegal                                      16.3            44.8
# Sierra Leone                                  8.6            30.7
# Sudan                                         8.0            45.4
# Tanzania                                     11.5            43.8
# East Timor                                   25.0            17.3
# Togo                                         16.9            48.2
# Uganda                                       11.7            33.7
# Zambia                                       16.2            15.6
#
#                                   Unemployment rate  Urban_population  \
# Country
# Afghanistan                                   11.12         9797273.0
# Angola                                         6.89        21061025.0
# Benin                                          2.23         5648149.0
# Burkina Faso                                   6.26         6092349.0
# Ivory Coast                                    3.32        13176900.0
# Cameroon                                       3.38        14741256.0
# Central African Republic                       3.68         1982064.0
# Republic of the Congo                          9.47         3625010.0
# Democratic Republic of the Congo               4.24        39095679.0
# Gabon                                         20.00         1949694.0
# The Gambia                                     9.06         1453958.0
# Ghana                                          4.33        17249054.0
# Kenya                                          2.64        14461523.0
# Laos                                           0.63         2555552.0
# Lesotho                                       23.41          607508.0
# Liberia                                        2.81         2548426.0
# Madagascar                                     1.76        10210849.0
# Malawi                                         5.65         3199301.0
# Mali                                           7.22         8479688.0
# Mozambique                                     3.24        11092106.0
# Niger                                          0.47         3850231.0
# Nigeria                                        8.10       102806948.0
# Pakistan                                       4.45        79927762.0
# Papua New Guinea                               2.46         1162834.0
# Senegal                                        6.60         7765706.0
# Sierra Leone                                   4.43         3319366.0
# Sudan                                         16.53        14957233.0
# Tanzania                                       1.98        20011885.0
# East Timor                                     4.55          400182.0
# Togo                                           2.04         3414638.0
# Uganda                                         1.84        10784516.0
# Zambia                                        11.43         7871713.0
#
#                                   Cluster_Id
# Country
# Afghanistan                                1
# Angola                                     1
# Benin                                      1
# Burkina Faso                               1
# Ivory Coast                                1
# Cameroon                                   1
# Central African Republic                   1
# Republic of the Congo                      1
# Democratic Republic of the Congo           1
# Gabon                                      1
# The Gambia                                 1
# Ghana                                      1
# Kenya                                      1
# Laos                                       1
# Lesotho                                    1
# Liberia                                    1
# Madagascar                                 1
# Malawi                                     1
# Mali                                       1
# Mozambique                                 1
# Niger                                      1
# Nigeria                                    1
# Pakistan                                   1
# Papua New Guinea                           1
# Senegal                                    1
# Sierra Leone                               1
# Sudan                                      1
# Tanzania                                   1
# East Timor                                 1
# Togo                                       1
# Uganda                                     1
# Zambia                                     1
#
# [32 rows x 27 columns]

# %%
df[df['Cluster_Id']==2]
# Out:
#                Density\n(P/Km2)  Agricultural Land( %)  Land Area(Km2)  \
# Country
# China                     153.0                   56.2       9596960.0
# India                     464.0                   60.4       3287263.0
# Russia                      9.0                   13.3      17098240.0
# United States              36.0                   44.4       9833517.0
#
#                Armed Forces size  Birth Rate  Co2-Emissions     CPI  \
# Country
# China                  2695000.0       10.90      9893038.0  125.08
# India                  3031000.0       17.86      2407672.0  180.44
# Russia                 1454000.0       11.50      1732027.0  180.75
# United States          1359000.0       11.60      5006302.0  117.24
#
#                CPI Change (%)  Fertility Rate  Forested Area (%)  ...  \
# Country                                                           ...
# China                     2.9            1.69               22.4  ...
# India                     7.7            2.22               23.8  ...
# Russia                    4.5            1.57               49.8  ...
# United States             7.5            1.73               33.9  ...
#
#                Minimum wage  Out of pocket health expenditure  \
# Country
# China                  0.87                              32.4
# India                  0.30                              65.1
# Russia                 0.53                              36.4
# United States          7.25                              11.1
#
#                Physicians per thousand    Population  \
# Country
# China                             1.98  1.397715e+09
# India                             0.86  1.366418e+09
# Russia                            4.01  1.443735e+08
# United States                     2.61  3.282395e+08
#
#                Population: Labor force participation (%)  Tax revenue (%)  \
# Country
# China                                               68.0              9.4
# India                                               49.3             11.2
# Russia                                              61.8             11.4
# United States                                       62.0              9.6
#
#                Total tax rate  Unemployment rate  Urban_population  Cluster_Id
# Country
# China                    59.2               4.32       842933962.0           2
# India                    49.7               5.36       471031528.0           2
# Russia                   46.2               4.59       107683889.0           2
# United States            36.6              14.70       270663028.0           2
#
# [4 rows x 27 columns]

# %%
df[df['Cluster_Id']==3]
# Out:
#                      Density\n(P/Km2)  Agricultural Land( %)  Land Area(Km2)  \
# Country
# Albania                         105.0                   43.1         28748.0
# Algeria                          18.0                   17.4       2381741.0
# Argentina                        17.0                   54.3       2780400.0
# Armenia                         104.0                   58.9         29743.0
# Azerbaijan                      123.0                   57.7         86600.0
# The Bahamas                      39.0                    1.4         13880.0
# Bangladesh                     1265.0                   70.6        148460.0
# Belize                           17.0                    7.0         22966.0
# Bhutan                           20.0                   13.6         38394.0
# Botswana                          4.0                   45.6        581730.0
# Brazil                           25.0                   33.9       8515770.0
# Cape Verde                      138.0                   19.6          4033.0
# Colombia                         46.0                   40.3       1138910.0
# Costa Rica                      100.0                   34.5         51100.0
# Dominican Republic              225.0                   48.7         48670.0
# El Salvador                     313.0                   76.4         21041.0
# Fiji                             49.0                   23.3         18274.0
# Georgia                          57.0                   34.5         69700.0
# Guatemala                       167.0                   36.0        108889.0
# Honduras                         89.0                   28.9        112090.0
# Indonesia                       151.0                   31.5       1904569.0
# Iran                             52.0                   28.2       1648195.0
# Iraq                             93.0                   21.4        438317.0
# Jamaica                         273.0                   41.0         10991.0
# Jordan                          115.0                   12.0         89342.0
# Kazakhstan                        7.0                   80.4       2724900.0
# Kuwait                          240.0                    8.4         17818.0
# Kyrgyzstan                       34.0                   55.0        199951.0
# Lebanon                         667.0                   64.3         10400.0
# Malaysia                         99.0                   26.3        329847.0
# Mauritius                       626.0                   42.4          2040.0
# Mexico                           66.0                   54.6       1964375.0
# Moldova                         123.0                   74.2         33851.0
# Mongolia                          2.0                   71.5       1564116.0
# Morocco                          83.0                   68.5        446550.0
# Myanmar                          83.0                   19.5        676578.0
# Nepal                           203.0                   28.7        147181.0
# Nicaragua                        55.0                   42.1        130370.0
# Oman                             16.0                    4.6        309500.0
# Paraguay                         18.0                   55.1        406752.0
# Peru                             26.0                   18.5       1285216.0
# Philippines                     368.0                   41.7        300000.0
# Saudi Arabia                     16.0                   80.8       2149690.0
# Serbia                          100.0                   39.3         77474.0
# Sri Lanka                       341.0                   43.7         65610.0
# Syria                            95.0                   75.8        185180.0
# Tajikistan                       68.0                   34.1        144100.0
# Thailand                        137.0                   43.3        513120.0
# Trinidad and Tobago             273.0                   10.5          5128.0
# Tunisia                          76.0                   64.8        163610.0
# Turkey                          110.0                   49.8        783562.0
# Ukraine                          75.0                   71.7        603550.0
# Vietnam                         314.0                   39.3        331210.0
#
#                      Armed Forces size  Birth Rate  Co2-Emissions     CPI  \
# Country
# Albania                         9000.0       11.78         4536.0  119.05
# Algeria                       317000.0       24.28       150006.0  151.36
# Argentina                     105000.0       17.02       201348.0  232.75
# Armenia                        49000.0       13.99         5156.0  129.18
# Azerbaijan                     82000.0       14.00        37620.0  156.32
# The Bahamas                     1000.0       13.97         1786.0  116.22
# Bangladesh                    221000.0       18.18        84246.0  179.68
# Belize                          2000.0       20.79          568.0  105.68
# Bhutan                          6000.0       17.26         1261.0  167.18
# Botswana                        9000.0       24.82         6340.0  149.75
# Brazil                        730000.0       13.92       462299.0  167.40
# Cape Verde                      1000.0       19.49          543.0  110.50
# Colombia                      481000.0       14.88        97814.0  140.95
# Costa Rica                     10000.0       13.97         8023.0  128.85
# Dominican Republic             71000.0       19.51        25258.0  135.50
# El Salvador                    42000.0       18.25         7169.0  111.23
# Fiji                            4000.0       21.28         2046.0  132.30
# Georgia                        26000.0       13.47        10128.0  133.61
# Guatemala                      43000.0       24.56        16777.0  142.92
# Honduras                       23000.0       21.60         9813.0  150.34
# Indonesia                     676000.0       18.07       563325.0  151.18
# Iran                          563000.0       18.78       661710.0  550.93
# Iraq                          209000.0       29.08       190061.0  119.86
# Jamaica                         4000.0       16.10         8225.0  162.47
# Jordan                        116000.0       21.98        25108.0  125.60
# Kazakhstan                     71000.0       21.77       247207.0  182.75
# Kuwait                         25000.0       13.94        98734.0  126.60
# Kyrgyzstan                     21000.0       27.10         9787.0  155.68
# Lebanon                        80000.0       17.55        24796.0  130.02
# Malaysia                      136000.0       16.75       248289.0  121.46
# Mauritius                       3000.0       10.20         4349.0  129.91
# Mexico                        336000.0       17.60       486406.0  141.54
# Moldova                         7000.0       10.10         5115.0  166.20
# Mongolia                       18000.0       24.13        25368.0  195.76
# Morocco                       246000.0       18.94        61276.0  111.07
# Myanmar                       513000.0       17.55        25280.0  168.18
# Nepal                         112000.0       19.89         9105.0  188.73
# Nicaragua                      12000.0       20.64         5592.0  162.74
# Oman                           47000.0       19.19        63457.0  113.53
# Paraguay                       27000.0       20.57         7407.0  143.82
# Peru                          158000.0       17.95        57414.0  129.78
# Philippines                   153000.0       20.55       122287.0  129.61
# Saudi Arabia                  252000.0       17.80       563449.0  118.40
# Serbia                         32000.0        9.20        45221.0  144.00
# Sri Lanka                     317000.0       15.83        23362.0  155.53
# Syria                         239000.0       23.69        28830.0  143.20
# Tajikistan                     17000.0       30.76         5310.0  148.57
# Thailand                      455000.0       10.34       283763.0  113.27
# Trinidad and Tobago             4000.0       12.94        43868.0  141.75
# Tunisia                        48000.0       17.56        29937.0  155.33
# Turkey                        512000.0       16.03       372725.0  234.44
# Ukraine                       297000.0        8.70       202250.0  281.66
# Vietnam                       522000.0       16.75       192668.0  163.52
#
#                      CPI Change (%)  Fertility Rate  Forested Area (%)  ...  \
# Country                                                                 ...
# Albania                         1.4            1.62               28.1  ...
# Algeria                         2.0            3.02                0.8  ...
# Argentina                      53.5            2.26                9.8  ...
# Armenia                         1.4            1.76               11.7  ...
# Azerbaijan                      2.6            1.73               14.1  ...
# The Bahamas                     2.5            1.75               51.4  ...
# Bangladesh                      5.6            2.04               11.0  ...
# Belize                         -0.9            2.31               59.7  ...
# Bhutan                          2.7            1.98               72.5  ...
# Botswana                        2.8            2.87               18.9  ...
# Brazil                          3.7            1.73               58.9  ...
# Cape Verde                      1.1            2.27               22.5  ...
# Colombia                        3.5            1.81               52.7  ...
# Costa Rica                      2.1            1.75               54.6  ...
# Dominican Republic              1.8            2.35               41.7  ...
# El Salvador                     0.1            2.04               12.6  ...
# Fiji                            1.8            2.77               55.9  ...
# Georgia                         4.9            2.06               40.6  ...
# Guatemala                       3.7            2.87               32.7  ...
# Honduras                        4.4            2.46               40.0  ...
# Indonesia                       3.0            2.31               49.9  ...
# Iran                           39.9            2.14                6.6  ...
# Iraq                            0.4            3.67                1.9  ...
# Jamaica                         3.9            1.98               30.9  ...
# Jordan                          0.8            2.76                1.1  ...
# Kazakhstan                      5.2            2.84                1.2  ...
# Kuwait                          1.1            2.08                0.4  ...
# Kyrgyzstan                      1.1            3.30                3.3  ...
# Lebanon                         3.0            2.09               13.4  ...
# Malaysia                        0.7            2.00               67.6  ...
# Mauritius                       0.4            1.41               19.0  ...
# Mexico                          3.6            2.13               33.9  ...
# Moldova                         4.8            1.26               12.6  ...
# Mongolia                        7.3            2.90                8.0  ...
# Morocco                         0.2            2.42               12.6  ...
# Myanmar                         8.8            2.15               43.6  ...
# Nepal                           5.6            1.92               25.4  ...
# Nicaragua                       5.4            2.40               25.9  ...
# Oman                            0.1            2.89                0.0  ...
# Paraguay                        2.8            2.43               37.7  ...
# Peru                            2.1            2.25               57.7  ...
# Philippines                     2.5            2.58               27.8  ...
# Saudi Arabia                   -1.2            2.32                0.5  ...
# Serbia                          1.8            1.49               31.1  ...
# Sri Lanka                       3.5            2.20               32.9  ...
# Syria                          36.7            2.81                2.7  ...
# Tajikistan                      6.0            3.59                3.0  ...
# Thailand                        0.7            1.53               32.2  ...
# Trinidad and Tobago             1.0            1.73               46.0  ...
# Tunisia                         6.7            2.20                6.8  ...
# Turkey                         15.2            2.07               15.4  ...
# Ukraine                         7.9            1.30               16.7  ...
# Vietnam                         2.8            2.05               48.1  ...
#
#                      Minimum wage  Out of pocket health expenditure  \
# Country
# Albania                      1.12                              56.9
# Algeria                      0.95                              28.1
# Argentina                    3.35                              17.6
# Armenia                      0.66                              81.6
# Azerbaijan                   0.47                              78.6
# The Bahamas                  5.25                              27.8
# Bangladesh                   0.51                              71.8
# Belize                       1.65                              22.7
# Bhutan                       0.32                              19.8
# Botswana                     0.29                               5.3
# Brazil                       1.53                              28.3
# Cape Verde                   0.68                              23.2
# Colombia                     1.23                              18.3
# Costa Rica                   1.84                              21.5
# Dominican Republic           0.40                              43.7
# El Salvador                  0.50                              27.9
# Fiji                         1.28                              21.4
# Georgia                      0.05                              57.3
# Guatemala                    1.60                              55.8
# Honduras                     1.01                              49.1
# Indonesia                    0.48                              48.3
# Iran                         1.58                              39.7
# Iraq                         1.24                              76.5
# Jamaica                      1.33                              23.7
# Jordan                       1.49                              25.1
# Kazakhstan                   0.41                              38.8
# Kuwait                       0.95                              14.4
# Kyrgyzstan                   0.09                              48.2
# Lebanon                      2.15                              32.1
# Malaysia                     0.93                              36.7
# Mauritius                    0.38                              50.7
# Mexico                       0.49                              41.4
# Moldova                      0.31                              46.2
# Mongolia                     0.65                              39.3
# Morocco                      1.60                              53.1
# Myanmar                      0.39                              73.9
# Nepal                        0.36                              60.4
# Nicaragua                    0.54                              36.0
# Oman                         4.33                               6.4
# Paraguay                     1.55                              36.5
# Peru                         1.28                              30.9
# Philippines                  1.12                              53.5
# Saudi Arabia                 3.85                              15.0
# Serbia                       1.57                              40.6
# Sri Lanka                    0.35                              38.4
# Syria                        1.02                              53.7
# Tajikistan                   0.23                              63.1
# Thailand                     1.06                              11.8
# Trinidad and Tobago          2.25                              37.3
# Tunisia                      0.47                              39.8
# Turkey                       3.45                              16.9
# Ukraine                      0.84                              47.8
# Vietnam                      0.73                              43.5
#
#                      Physicians per thousand   Population  \
# Country
# Albania                                 1.20    2854191.0
# Algeria                                 1.72   43053054.0
# Argentina                               3.96   44938712.0
# Armenia                                 4.40    2957731.0
# Azerbaijan                              3.45   10023318.0
# The Bahamas                             1.94     389482.0
# Bangladesh                              0.58  167310838.0
# Belize                                  1.12     390353.0
# Bhutan                                  0.42     727145.0
# Botswana                                0.37    2346179.0
# Brazil                                  2.15  212559417.0
# Cape Verde                              0.77     483628.0
# Colombia                                2.18   50339443.0
# Costa Rica                              2.89    5047561.0
# Dominican Republic                      1.56   10738958.0
# El Salvador                             1.57    6453553.0
# Fiji                                    0.84     889953.0
# Georgia                                 7.12    3720382.0
# Guatemala                               0.35   16604026.0
# Honduras                                0.31    9746117.0
# Indonesia                               0.43  270203917.0
# Iran                                    1.58   82913906.0
# Iraq                                    0.71   39309783.0
# Jamaica                                 1.31    2948279.0
# Jordan                                  2.32   10101694.0
# Kazakhstan                              3.25   18513930.0
# Kuwait                                  2.58    4207083.0
# Kyrgyzstan                              1.88    6456900.0
# Lebanon                                 2.10    6855713.0
# Malaysia                                1.51   32447385.0
# Mauritius                               2.53    1265711.0
# Mexico                                  2.38  126014024.0
# Moldova                                 3.21    2657637.0
# Mongolia                                2.86    3225167.0
# Morocco                                 0.73   36910560.0
# Myanmar                                 0.68   54045420.0
# Nepal                                   0.75   28608710.0
# Nicaragua                               0.98    6545502.0
# Oman                                    2.00    5266535.0
# Paraguay                                1.35    7044636.0
# Peru                                    1.27   32510453.0
# Philippines                             0.60  108116615.0
# Saudi Arabia                            2.61   34268528.0
# Serbia                                  3.11    6944975.0
# Sri Lanka                               1.00   21803000.0
# Syria                                   1.22   17070135.0
# Tajikistan                              1.70    9321018.0
# Thailand                                0.81   69625582.0
# Trinidad and Tobago                     4.17    1394973.0
# Tunisia                                 1.30   11694719.0
# Turkey                                  1.85   83429615.0
# Ukraine                                 2.99   44385155.0
# Vietnam                                 0.82   96462106.0
#
#                      Population: Labor force participation (%)  \
# Country
# Albania                                                   55.7
# Algeria                                                   41.2
# Argentina                                                 61.3
# Armenia                                                   55.6
# Azerbaijan                                                66.5
# The Bahamas                                               74.6
# Bangladesh                                                59.0
# Belize                                                    65.1
# Bhutan                                                    66.7
# Botswana                                                  70.8
# Brazil                                                    63.9
# Cape Verde                                                60.5
# Colombia                                                  68.8
# Costa Rica                                                62.1
# Dominican Republic                                        64.3
# El Salvador                                               59.1
# Fiji                                                      57.6
# Georgia                                                   68.3
# Guatemala                                                 62.3
# Honduras                                                  68.8
# Indonesia                                                 67.5
# Iran                                                      44.7
# Iraq                                                      43.0
# Jamaica                                                   66.0
# Jordan                                                    39.3
# Kazakhstan                                                68.8
# Kuwait                                                    73.5
# Kyrgyzstan                                                59.8
# Lebanon                                                   47.0
# Malaysia                                                  64.3
# Mauritius                                                 58.3
# Mexico                                                    60.7
# Moldova                                                   43.1
# Mongolia                                                  59.7
# Morocco                                                   45.3
# Myanmar                                                   61.7
# Nepal                                                     83.8
# Nicaragua                                                 66.4
# Oman                                                      72.4
# Paraguay                                                  72.1
# Peru                                                      77.6
# Philippines                                               59.6
# Saudi Arabia                                              55.9
# Serbia                                                    54.9
# Sri Lanka                                                 53.9
# Syria                                                     44.1
# Tajikistan                                                42.0
# Thailand                                                  67.3
# Trinidad and Tobago                                       60.0
# Tunisia                                                   46.1
# Turkey                                                    52.8
# Ukraine                                                   54.2
# Vietnam                                                   77.4
#
#                      Tax revenue (%)  Total tax rate  Unemployment rate  \
# Country
# Albania                         18.6            36.6              12.33
# Algeria                         37.2            66.1              11.70
# Argentina                       10.1           106.3               9.79
# Armenia                         20.9            22.6              16.99
# Azerbaijan                      13.0            40.7               5.51
# The Bahamas                     14.8            33.8              10.36
# Bangladesh                       8.8            33.4               4.19
# Belize                          26.3            31.1               6.41
# Bhutan                          16.0            35.3               2.34
# Botswana                        19.5            25.1              18.19
# Brazil                          14.2            65.1              12.08
# Cape Verde                      20.1            37.5              12.25
# Colombia                        14.4            71.2               9.71
# Costa Rica                      13.6            58.3              11.85
# Dominican Republic              13.0            48.8               5.84
# El Salvador                     18.1            36.4               4.11
# Fiji                            24.2            32.1               4.10
# Georgia                         21.7             9.9              14.40
# Guatemala                       10.6            35.2               2.46
# Honduras                        17.3            39.1               5.39
# Indonesia                       10.2            30.1               4.69
df_reset = df.reset_index()
df_reset.head()
# Out:
#        Country  Density\n(P/Km2)  Agricultural Land( %)  Land Area(Km2)  \
# 0  Afghanistan              60.0                   58.1        652230.0
# 1      Albania             105.0                   43.1         28748.0
# 2      Algeria              18.0                   17.4       2381741.0
# 3       Angola              26.0                   47.5       1246700.0
# 4    Argentina              17.0                   54.3       2780400.0
#
#    Armed Forces size  Birth Rate  Co2-Emissions     CPI  CPI Change (%)  \
# 0           323000.0       32.49         8672.0  149.90             2.3
# 1             9000.0       11.78         4536.0  119.05             1.4
# 2           317000.0       24.28       150006.0  151.36             2.0
# 3           117000.0       40.73        34693.0  261.73            17.1
# 4           105000.0       17.02       201348.0  232.75            53.5
#
#    Fertility Rate  ...  Minimum wage  Out of pocket health expenditure  \
# 0            4.47  ...          0.43                              78.4
# 1            1.62  ...          1.12                              56.9
# 2            3.02  ...          0.95                              28.1
# 3            5.52  ...          0.71                              33.4
# 4            2.26  ...          3.35                              17.6
#
#    Physicians per thousand  Population  \
# 0                     0.28  38041754.0
# 1                     1.20   2854191.0
# 2                     1.72  43053054.0
# 3                     0.21  31825295.0
# 4                     3.96  44938712.0
#
#    Population: Labor force participation (%)  Tax revenue (%)  Total tax rate  \
# 0                                       48.9              9.3            71.4
# 1                                       55.7             18.6            36.6
# 2                                       41.2             37.2            66.1
# 3                                       77.5              9.2            49.1
# 4                                       61.3             10.1           106.3
#
#    Unemployment rate  Urban_population  Cluster_Id
# 0              11.12         9797273.0           1
# 1              12.33         1747593.0           3
# 2              11.70        31510100.0           3
# 3               6.89        21061025.0           1
# 4               9.79        41339571.0           3
#
# [5 rows x 28 columns]

# %%
clustered_countries = df_reset.groupby('Cluster_Id')['Country'].count()
clustered_countries
# Out:
# Cluster_Id
# 0    31
# 1    32
# 2     4
# 3    53
# Name: Country, dtype: int64

# %% [markdown]
# # Scatter plots displaying clusters

# %%
#scatter plot of highly correlated variables(from correlation metrix)
sns.lmplot(x='Birth Rate', y='Fertility Rate', data=df, hue='Cluster_Id', fit_reg=False)

# %%
#scatter plot of Low correlated variables(from correlation metrix)
sns.lmplot(x='Birth Rate', y='Life expectancy', data=df, hue='Cluster_Id', fit_reg=False)

# %%
#scatter plot of economic variables
sns.lmplot(x='Co2-Emissions', y='GDP', data=df, hue='Cluster_Id', fit_reg=False)

# %%
#scatter plot of environmental variables
sns.lmplot(y='Co2-Emissions', x='Agricultural Land( %)', data=df, hue='Cluster_Id', fit_reg=False)

# %%
#scatter plot of Educational variables
sns.lmplot(x='Gross primary education enrollment (%)', y='Gross tertiary education enrollment (%)', data=df, hue='Cluster_Id', fit_reg=False)

# %%
#scatter plot of Population variables
sns.lmplot(x='Population', y='Urban_population', data=df, hue='Cluster_Id', fit_reg=False)

# %%
#scatter plot of Tax variables
sns.lmplot(x='Total tax rate', y='Tax revenue (%)', data=df, hue='Cluster_Id', fit_reg=False)

# %% [markdown]
# In the next Part of this analysis i will carry out the same analysis with a didfferent clustering models and conclude on how the results vary depending on what model is selected.
